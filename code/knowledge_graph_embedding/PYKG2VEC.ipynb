# %% [markdown]
# ## **PYKG2VEC**

# %% [markdown]
# **Clone pykg2vec**

# %%
! git clone https://github.com/Sujit-O/pykg2vec.git
# Out:
# Cloning into 'pykg2vec'...
# remote: Enumerating objects: 8521, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 8521 (delta 31), reused 38 (delta 16), pack-reused 8455
# Receiving objects: 100% (8521/8521), 9.52 MiB | 25.33 MiB/s, done.
# Resolving deltas: 100% (6336/6336), done.

# %% [markdown]
# **Open the folder pykg2vec**

# %%
# %cd pykg2vec/
# Out:
# /content/pykg2vec

# %% [markdown]
#  **Setup pykg2vec**

# %%
# !python setup.py install
# Out:
#      |████████████████████████████████| 3.1 MB 5.0 MB/s
#      |████████████████████████████████| 90 kB 4.0 MB/s
#      |████████████████████████████████| 100 kB 3.9 MB/s
#      |████████████████████████████████| 84 kB 2.0 MB/s
#      |████████████████████████████████| 121 kB 5.5 MB/s
# running install
# running bdist_egg
# running egg_info
# creating pykg2vec.egg-info
# writing pykg2vec.egg-info/PKG-INFO
# writing dependency_links to pykg2vec.egg-info/dependency_links.txt
# writing entry points to pykg2vec.egg-info/entry_points.txt
# writing requirements to pykg2vec.egg-info/requires.txt
# writing top-level names to pykg2vec.egg-info/top_level.txt
# writing manifest file 'pykg2vec.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'pykg2vec.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pykg2vec
# ...

# %% [markdown]
# **Goto examples folder**
#
# train.py is in the example folder

# %%
# %cd /content/pykg2vec/examples/
# Out:
# /content/pykg2vec/examples

# %%
# !ls
# Out:
# custom_hp.yaml	inference.py   pretrained     train.py
# custom_ss.yaml	__init__.py    README.txt     tune_model.py
# experiment.py	kgpipeline.py  test_file.npy

# %% [markdown]
# **Training using TransE**
#
#
# *   -mn : embedding algorithm (here TransE)
# *   -ds : Dataset

# %%
# !python train.py -mn TransE -ds kg1 -dsp /content
# Out:
# 2022-05-30 16:03:28,554 - pykg2vec.config - INFO -
# ------------------Global Setting--------------------
#                   lmbda : 0.1
#              batch_size : 128
#                  margin : 0.8
#               optimizer : adam
#                sampling : uniform
#                neg_rate : 1
#                  epochs : 100
#           learning_rate : 0.01
#             hidden_size : 50
#         ent_hidden_size : 50
#         rel_hidden_size : 50
#           hidden_size_1 : 10
#                 l1_flag : True
#                   alpha : 0.1
#            filter_sizes : [1, 2, 3]
#             num_filters : 50
#     feature_map_dropout : 0.2
#           input_dropout : 0.3
#          hidden_dropout : 0.3
#         hidden_dropout1 : 0.4
#         hidden_dropout2 : 0.5
#         label_smoothing : 0.1
#                    cmax : 0.05
#                    cmin : 5.0
#     feature_permutation : 1
#          reshape_height : 20
#           reshape_width : 10
# ...

# %% [markdown]
# **Training using TransR**
#
#
#
#
# *   -mn : embedding algorithm (here TransR)
# *   -ds : Dataset

# %%
# !python train.py -mn TransR -ds kg1 -dsp /content
# Out:
# 2022-05-30 16:51:56,638 - pykg2vec.config - INFO -
# ------------------Global Setting--------------------
#                   lmbda : 0.1
#              batch_size : 128
#                  margin : 0.8
#               optimizer : adam
#                sampling : uniform
#                neg_rate : 1
#                  epochs : 100
#           learning_rate : 0.01
#             hidden_size : 50
#         ent_hidden_size : 50
#         rel_hidden_size : 50
#           hidden_size_1 : 10
#                 l1_flag : True
#                   alpha : 0.1
#            filter_sizes : [1, 2, 3]
#             num_filters : 50
#     feature_map_dropout : 0.2
#           input_dropout : 0.3
#          hidden_dropout : 0.3
#         hidden_dropout1 : 0.4
#         hidden_dropout2 : 0.5
#         label_smoothing : 0.1
#                    cmax : 0.05
#                    cmin : 5.0
#     feature_permutation : 1
#          reshape_height : 20
#           reshape_width : 10
# ...

# %% [markdown]
# Download output as zip

# %%
# !zip -r /content/embeddings.zip /content/embeddings/transe
# Out:
#   adding: content/embeddings/transe/ (stored 0%)
#   adding: content/embeddings/transe/rel_embedding.tsv (deflated 55%)
#   adding: content/embeddings/transe/ent_labels.tsv (deflated 60%)
#   adding: content/embeddings/transe/ent_embedding.tsv (deflated 58%)
#   adding: content/embeddings/transe/rel_labels.tsv (stored 0%)
